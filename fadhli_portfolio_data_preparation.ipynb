# %% [markdown]
# Import library python

# %%
import pandas as pd  # module untuk menganalisis dan editing dataframe
import numpy as np  # module untuk mengoperasikan matematika
import matplotlib.pyplot as plt  # modul untuk memvisualisasi data
import seaborn as sns  # module untuk memvisualisasi data
import os  # module untuk melalukan operasi jupyter

# %%
movies_data = pd.read_csv('C:/Users/muhammad fadhli/Documents/MySkill/movies_metadata.csv')

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
# ...

# %%
movies_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movies_data = movies_data.set_index("original_title") # mengubah index

# %%
movies_data.index
# Out:
# Index(['Toy Story', 'Jumanji', 'Grumpier Old Men', 'Waiting to Exhale',
#        'Father of the Bride Part II', 'Heat', 'Sabrina', 'Tom and Huck',
#        'Sudden Death', 'GoldenEye',
#        ...
#        'House of Horrors', 'Shadow of the Blair Witch', 'The Burkittsville 7',
#        'Caged Heat 3000', 'Robin Hood', 'رگ خواب', 'Siglo ng Pagluluwal',
#        'Betrayal', 'Satana likuyushchiy', 'Queerama'],
#       dtype='object', name='original_title', length=45463)

# %%
movies_data.loc["Queerama"] # memanggil data
# Out:
# adult                                                                 True
# belongs_to_collection                                                  NaN
# budget                                                                   0
# genres                                                                  []
# homepage                                                               NaN
# id                                                                  461257
# imdb_id                                                          tt6980792
# original_language                                                       en
# overview                 50 years after decriminalisation of homosexual...
# popularity                                                        0.163015
# poster_path                               /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
# production_companies                                                    []
# ...

# %%
movies_data = movies_data.reset_index() # mereset index

# %%
movies_data.head()
# Out:
#                 original_title  adult  \
# 0                    Toy Story   True
# 1                      Jumanji   True
# 2             Grumpier Old Men   True
# 3            Waiting to Exhale   True
# 4  Father of the Bride Part II   True
#
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
movies_data.loc[:, "original_title"]
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45458                        رگ خواب
# 45459            Siglo ng Pagluluwal
# 45460                       Betrayal
# 45461            Satana likuyushchiy
# 45462                       Queerama
# Name: original_title, Length: 45463, dtype: object

# %%
movies_data["release_date"] = pd.to_datetime(movies_data["release_date"])

# %%
movies_data["release_date"]
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45458          NaT
# 45459   2011-11-17
# 45460   2003-08-01
# 45461   1917-10-21
# 45462   2017-06-09
# Name: release_date, Length: 45463, dtype: datetime64[ns]

# %%
movies_data["status"].unique()  #Mengecek isi value dalam kolom yang bersifat kategorikal
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
english_released = movies_data[(movies_data["original_language"] == "en") &\
                               (movies_data["status"] == "Released")]  # memfilter 2 kolom dengan and

# %%
english_released
# Out:
#                     original_title  adult  \
# 0                        Toy Story   True
# 1                          Jumanji   True
# 2                 Grumpier Old Men   True
# 3                Waiting to Exhale   True
# 4      Father of the Bride Part II   True
# ...                            ...    ...
# 45456              Caged Heat 3000   True
# 45457                   Robin Hood   True
# 45460                     Betrayal   True
# 45461          Satana likuyushchiy   True
# 45462                     Queerama   True
#
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...

# %%
english_released.sort_values("budget", ascending = False).head()
# Out:
#                                     original_title  adult  \
# 17124  Pirates of the Caribbean: On Stranger Tides   True
# 11827     Pirates of the Caribbean: At World's End   True
# 26557                      Avengers: Age of Ultron   True
# 11067                             Superman Returns   True
# 18685                                  John Carter   True
#
#                                    belongs_to_collection     budget  \
# 17124  {'id': 295, 'name': 'Pirates of the Caribbean ...  380000000
# 11827  {'id': 295, 'name': 'Pirates of the Caribbean ...  300000000
# 26557  {'id': 86311, 'name': 'The Avengers Collection...  280000000
# 11067  {'id': 8537, 'name': 'Superman Collection', 'p...  270000000
# 18685                                                NaN  260000000
#
#                                                   genres  \
# 17124  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 11827  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
english_released.sort_values(["budget", "revenue"], ascending = [False, False]).head()
# Out:
#                                     original_title  adult  \
# 17124  Pirates of the Caribbean: On Stranger Tides   True
# 11827     Pirates of the Caribbean: At World's End   True
# 26557                      Avengers: Age of Ultron   True
# 11067                             Superman Returns   True
# 44839                Transformers: The Last Knight   True
#
#                                    belongs_to_collection     budget  \
# 17124  {'id': 295, 'name': 'Pirates of the Caribbean ...  380000000
# 11827  {'id': 295, 'name': 'Pirates of the Caribbean ...  300000000
# 26557  {'id': 86311, 'name': 'The Avengers Collection...  280000000
# 11067  {'id': 8537, 'name': 'Superman Collection', 'p...  270000000
# 44839  {'id': 8650, 'name': 'Transformers Collection'...  260000000
#
#                                                   genres  \
# 17124  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 11827  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
english_released.duplicated().sum()  # menghitung data yang duplicated
# Out:
# 9

# %%
english_released[english_released.duplicated()] # menampilkan data yang duplicated
# Out:
#                          original_title  adult  \
# 9327                        The Warrior   True
# 21164                       The Tempest   True
# 21853                      The Congress   True
# 22150                  Days of Darkness   True
# 24843                              Deal   True
# 28859                              Nana   True
# 35795  Why We Fight: Divide and Conquer   True
# 38868                        The Viking   True
# 40273              Seven Years Bad Luck   True
#
#                                    belongs_to_collection  budget  \
# 9327                                                 NaN       0
# 21164                                                NaN       0
# 21853                                                NaN       0
# 22150                                                NaN       0
# 24843                                                NaN       0
# 28859                                                NaN       0
# ...

# %%
english_released.duplicated(subset = "original_title").sum() # menghitung jumlah data duplicate berdasarkan kolom
# Out:
# 1746

# %%
english_released.duplicated(subset = "original_title")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45456    False
# 45457     True
# 45460     True
# 45461    False
# 45462    False
# Length: 31952, dtype: bool

# %%
english_released[english_released.duplicated(subset = "original_title", keep = False)].sort_values("original_title")
# untuk melihat data duplicate
# Out:
#                      original_title  adult  \
# 15200                  12 Angry Men   True
# 1161                   12 Angry Men   True
# 20847  20,000 Leagues Under the Sea   True
# 13003  20,000 Leagues Under the Sea   True
# 24108  20,000 Leagues Under the Sea   True
# ...                             ...    ...
# 11646                        Zodiac   True
# 37896                          Zoom   True
# 11171                          Zoom   True
# 5761                           Zulu   True
# 24662                          Zulu   True
#
#                                    belongs_to_collection    budget  \
# 15200                                                NaN         0
# 1161                                                 NaN    350000
# 20847                                                NaN         0
# 13003                                                NaN    200000
# 24108                                                NaN         0
# ...

# %%
english_released.drop_duplicates(inplace = True) # menghapus nilai yang duplicate
# Out:
# C:\Users\muhammad fadhli\AppData\Local\Temp\ipykernel_17064\1486727925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_released.drop_duplicates(inplace = True) # menghapus nilai yang duplicate

# %%
english_released.duplicated().sum()
# Out:
# 0

# %%
english_released.isna().sum() # menghitung kolom yang terdapat missing values
# Out:
# original_title               0
# adult                        0
# belongs_to_collection    28845
# budget                       0
# genres                       0
# homepage                 25842
# id                           0
# imdb_id                     11
# original_language            0
# overview                    64
# popularity                   0
# poster_path                311
# production_companies         0
# production_countries         0
# release_date                59
# revenue                      0
# runtime                      6
# spoken_languages             0
# status                       0
# tagline                  14114
# title                        0
# video                        0
# vote_average                 0
# vote_count                   0
# dtype: int64

# %%
english_released.isna().mean() # menghitung presentase missing values pada tiap kolom
# Out:
# original_title           0.000000
# adult                    0.000000
# belongs_to_collection    0.903015
# budget                   0.000000
# genres                   0.000000
# homepage                 0.809004
# id                       0.000000
# imdb_id                  0.000344
# original_language        0.000000
# overview                 0.002004
# popularity               0.000000
# poster_path              0.009736
# production_companies     0.000000
# production_countries     0.000000
# release_date             0.001847
# revenue                  0.000000
# runtime                  0.000188
# spoken_languages         0.000000
# status                   0.000000
# tagline                  0.441850
# title                    0.000000
# video                    0.000000
# vote_average             0.000000
# vote_count               0.000000
# dtype: float64

# %%
english_released["tagline"] = english_released["tagline"].fillna("No Tagline") # mengisi nilai yang missing values
# Out:
# C:\Users\muhammad fadhli\AppData\Local\Temp\ipykernel_17064\2275187781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_released["tagline"] = english_released["tagline"].fillna("No Tagline") # mengisi nilai yang missing values

# %%
english_released["tagline"].isna().sum()
# Out:
# 0

# %%
english_released.isna().sum()
# Out:
# original_title               0
# adult                        0
# belongs_to_collection    28845
# budget                       0
# genres                       0
# homepage                 25842
# id                           0
# imdb_id                     11
# original_language            0
# overview                    64
# popularity                   0
# poster_path                311
# production_companies         0
# production_countries         0
# release_date                59
# revenue                      0
# runtime                      6
# spoken_languages             0
# status                       0
# tagline                      0
# title                        0
# video                        0
# vote_average                 0
# vote_count                   0
# dtype: int64

# %%
english_released["belongs_to_collection"] = english_released["belongs_to_collection"].fillna("No Data")
# Out:
# C:\Users\muhammad fadhli\AppData\Local\Temp\ipykernel_17064\1562159728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_released["belongs_to_collection"] = english_released["belongs_to_collection"].fillna("No Data")

# %%
english_released["homepage"] = english_released["homepage"].fillna("No Data")
# Out:
# C:\Users\muhammad fadhli\AppData\Local\Temp\ipykernel_17064\673372930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_released["homepage"] = english_released["homepage"].fillna("No Data")

# %%
english_released["poster_path"] = english_released["poster_path"].fillna("No Data")
# Out:
# C:\Users\muhammad fadhli\AppData\Local\Temp\ipykernel_17064\1481162162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_released["poster_path"] = english_released["poster_path"].fillna("No Data")

# %%
english_released.dropna(inplace = True)
# Out:
# C:\Users\muhammad fadhli\AppData\Local\Temp\ipykernel_17064\3663514540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_released.dropna(inplace = True)

# %%
english_released.isna().sum()
# Out:
# original_title           0
# adult                    0
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
english_released
# Out:
#                     original_title  adult  \
# 0                        Toy Story   True
# 1                          Jumanji   True
# 2                 Grumpier Old Men   True
# 3                Waiting to Exhale   True
# 4      Father of the Bride Part II   True
# ...                            ...    ...
# 45456              Caged Heat 3000   True
# 45457                   Robin Hood   True
# 45460                     Betrayal   True
# 45461          Satana likuyushchiy   True
# 45462                     Queerama   True
#
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                No Data  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                No Data  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...

# %%
english_released.sort_values("vote_count", ascending = False)
# Out:
#                                       original_title  adult  \
# 15480                                      Inception   True
# 12481                                The Dark Knight   True
# 14551                                         Avatar   True
# 17818                                   The Avengers   True
# 26563                                       Deadpool   True
# ...                                              ...    ...
# 33968                                The Sea Serpent   True
# 33988                                   Le Rossignol   True
# 34061                                          Mommy   True
# 34104  Fuori uno sotto un altro, arriva il Passatore   True
# 45462                                       Queerama   True
#
#                                    belongs_to_collection     budget  \
# 15480                                            No Data  160000000
# 12481  {'id': 263, 'name': 'The Dark Knight Collectio...  185000000
# ...

# %%
english_released[english_released["runtime"] > 60*3]
# Out:
#               original_title  adult  \
# 13                     Nixon   True
# 378               Wyatt Earp   True
# 522         Schindler's List   True
# 530               Short Cuts   True
# 583       Dances with Wolves   True
# ...                      ...    ...
# 44755              Hollywood   True
# 44760   The Putin Interviews   True
# 44924         Five Came Back   True
# 44959  5ive Days to Midnight   True
# 44992                  Jesus   True
#
#                                    belongs_to_collection    budget  \
# 13                                               No Data  44000000
# 378                                              No Data  63000000
# 522                                              No Data  22000000
# 530                                              No Data         0
# 583                                              No Data  22000000
# ...                                                  ...       ...
# ...

# %%
from google.cloud import bigquery

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'C:/Users/muhammad fadhli/Documents/coding.id/aqueous-freedom-398208-cfe0d4e567f2.json'

# %%
bigquery_client = bigquery.Client()

# %%
english_released.to_gbq(destination_table='portfolio_fadhli.portfolio', project_id='aqueous-freedom-398208', if_exists='replace')
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]

# %%
english_released.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31813 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   original_title         31813 non-null  object
#  1   adult                  31813 non-null  bool
#  2   belongs_to_collection  31813 non-null  object
#  3   budget                 31813 non-null  int64
#  4   genres                 31813 non-null  object
#  5   homepage               31813 non-null  object
#  6   id                     31813 non-null  int64
#  7   imdb_id                31813 non-null  object
#  8   original_language      31813 non-null  object
#  9   overview               31813 non-null  object
#  10  popularity             31813 non-null  float64
#  11  poster_path            31813 non-null  object
#  12  production_companies   31813 non-null  object
#  13  production_countries   31813 non-null  object
# ...
